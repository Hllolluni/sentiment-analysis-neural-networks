# %%
from keras.datasets import imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
import numpy as np

def bag_of_words(seq_array, dimension=10000):
    vector = np.zeros((len(seq_array), dimension))
    for i, seq in enumerate(seq_array):
        vector[i, seq] = 1
    return vector

xx_train = bag_of_words(x_train)
xx_test = bag_of_words(x_test)

yy_train = np.asarray(y_train).astype('float32')
yy_test = np.asarray(y_test).astype('float32')

# %%
from keras.models import Sequential
from keras.layers import Dense

ann_model = Sequential()
ann_model.add(Dense(64, activation='relu', input_shape=(10000,)))
ann_model.add(Dense(32, activation='relu'))
ann_model.add(Dense(16, activation='relu'))
ann_model.add(Dense(1, activation='sigmoid'))

x_val, x_train_part = xx_train[:10000], xx_train[10000:]

y_val, y_train_part = yy_train[:10000], yy_train[10000:]

ann_model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
history = ann_model.fit(x_train_part,
                        y_train_part,
                        epochs=20,
                        batch_size=512,
                        validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 5s 127ms/step - loss: 0.5225 - accuracy: 0.7352 - val_loss: 0.3484 - val_accuracy: 0.8732
# Epoch 2/20
# 30/30 [==============================] - 3s 88ms/step - loss: 0.2981 - accuracy: 0.8869 - val_loss: 0.2870 - val_accuracy: 0.8879
# Epoch 3/20
# 30/30 [==============================] - 2s 69ms/step - loss: 0.2244 - accuracy: 0.9147 - val_loss: 0.2797 - val_accuracy: 0.8867
# Epoch 4/20
# 30/30 [==============================] - 2s 71ms/step - loss: 0.1849 - accuracy: 0.9311 - val_loss: 0.2792 - val_accuracy: 0.8875
# Epoch 5/20
# 30/30 [==============================] - 3s 85ms/step - loss: 0.1439 - accuracy: 0.9474 - val_loss: 0.4724 - val_accuracy: 0.8329
# Epoch 6/20
# 30/30 [==============================] - 2s 82ms/step - loss: 0.1148 - accuracy: 0.9620 - val_loss: 0.3251 - val_accuracy: 0.8765
# Epoch 7/20
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense

ann_model = Sequential()
ann_model.add(Dense(32, activation='relu', input_shape=(10000,)))
ann_model.add(Dense(16, activation='relu'))
ann_model.add(Dense(1, activation='sigmoid'))

ann_model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
history = ann_model.fit(x_train_part,
                        y_train_part,
                        epochs=20,
                        batch_size=512,
                        validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 59ms/step - loss: 0.4825 - accuracy: 0.7906 - val_loss: 0.4282 - val_accuracy: 0.8067
# Epoch 2/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2999 - accuracy: 0.8875 - val_loss: 0.2922 - val_accuracy: 0.8904
# Epoch 3/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2246 - accuracy: 0.9219 - val_loss: 0.2827 - val_accuracy: 0.8871
# Epoch 4/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1806 - accuracy: 0.9390 - val_loss: 0.3289 - val_accuracy: 0.8669
# Epoch 5/20
# 30/30 [==============================] - 1s 42ms/step - loss: 0.1489 - accuracy: 0.9518 - val_loss: 0.3006 - val_accuracy: 0.8802
# Epoch 6/20
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1219 - accuracy: 0.9610 - val_loss: 0.3031 - val_accuracy: 0.8809
# Epoch 7/20
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
ann_model = Sequential()
ann_model.add(Dense(16, activation='relu', input_shape=(10000,)))
ann_model.add(Dense(1, activation='sigmoid'))
ann_model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
ann_model.fit(xx_train, yy_train, epochs=4, batch_size=512)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 2s 19ms/step - loss: 0.4565 - accuracy: 0.8223
# Epoch 2/4
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2908 - accuracy: 0.9014
# Epoch 3/4
# 49/49 [==============================] - 1s 18ms/step - loss: 0.2355 - accuracy: 0.9176
# Epoch 4/4
# 49/49 [==============================] - 1s 19ms/step - loss: 0.2062 - accuracy: 0.9279

# %%
results = ann_model.evaluate(xx_test, yy_test)
# Out:
# 782/782 [==============================] - 4s 4ms/step - loss: 0.2782 - accuracy: 0.8899
